# %%
#First import the packages we will use in this project

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjust the configuration of the plots we create

#Read in the data with pandas
df = pd.read_csv(r'C:\Users\folarin\Downloads\movies.csv')

# %%
#take a dive into the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# seeing if there is missing data
# looping through to achieve our target 

for col in df.columns:
    percent_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(percent_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
#From the check we caan see that 
#-rating has a few missing values
#-gross has a few missing value
#-budget has a lot of values missing
#And all these are values we may not necessarily find so we leave it ike that

# %%
#checking the data types 
print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#convert the data type of goss, votes, runntime and budget for more readability

df['gross'] = df['gross'].astype('Int64')
df['votes'] = df['votes'].astype('Int64')
df['runtime'] = df['runtime'].astype('Int64')
df['budget'] = df['budget'].astype('Int64')
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# dropping any form of duplicates 
df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#sorting values by gross in descending order
df = df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
#scatter plot budget vs gross

#note int64  will not plot with matplotlib #issues with pandas and mtpltlib
df['gross'] = df['gross'].astype('float64')
df['budget'] = df['budget'].astype('float64')


plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross earnings')
plt.xlabel('Budget for Films')
plt.ylabel('Gross Earnings')
plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country       budget  \
# ...

# %%
#plot budget vs gross with seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color": "blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
df.corr()  #this is making use of the default method of correlation pearson
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation matrix for numeric values')
plt.xlabel('Movie features')
plt.ylabel('Movie features')

plt.show()

# %%
df_tonumerize = df

# %%
#convert other fields that are object to numeric values that are distinct and unique for better correlation
for col_name in df_tonumerize.columns:
        if(df_tonumerize[col_name].dtype == 'object'):
            df_tonumerize[col_name] = df_tonumerize[col_name].astype('category')
            df_tonumerize[col_name] = df_tonumerize[col_name].cat.codes
    
df_tonumerize
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000      1155    1778
# 7445   535       5      0  2019       183    8.4   903000       162     743
# 3045  6896       5      6  1997       704    7.8  1100000      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000      1125    2550
# 7244   536       5      0  2018       192    8.4   897000       162     743
# ...    ...     ...    ...   ...       ...    ...      ...       ...     ...
# 7663  3705      -1      6  2020      2964    3.1       18      1500    2289
# 7664  1678      -1      4  2020      1107    4.7       36       774    2614
# 7665  4717      -1      6  2020       193    5.7       29      2061    2683
# 7666  2843      -1      6  2020      2817    NaN     <NA>      1184    1824
# 7667  5394      -1     10  2020       391    5.7        7      2165    3344
#
# ...

# %%
correlation__matrix = df_tonumerize.corr(method='pearson')

sns.heatmap(correlation__matrix, annot=True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
pd.set_option('display.max_rows', None) #to show the whole dataframe

# %%
correlation_mat = df_tonumerize.corr(method='pearson')

correlation_unstacked = correlation_mat.unstack()

correlation_unstacked   #unstacking the values for better readability
# Out:
# name      name        1.000000
#           rating     -0.008069
#           genre       0.016355
#           year        0.011453
#           released   -0.011311
#           score       0.017097
#           votes       0.013088
#           director    0.009079
#           writer      0.009081
#           star        0.006472
#           country    -0.010737
#           budget      0.023970
#           gross       0.005533
#           company     0.009211
#           runtime     0.010392
# rating    name       -0.008069
#           rating      1.000000
#           genre       0.072423
#           year        0.008779
#           released    0.016613
#           score      -0.001314
#           votes       0.033225
#           director    0.019483
#           writer     -0.005921
#           star        0.013405
#           country     0.081244
#           budget     -0.176002
#           gross      -0.107339
#           company    -0.032943
#           runtime     0.062145
# ...

# %%
sorted_pairs = correlation_unstacked.sort_values()

sorted_pairs
# Out:
# budget    genre      -0.356564
# genre     budget     -0.356564
#           gross      -0.235650
# gross     genre      -0.235650
# rating    budget     -0.176002
# budget    rating     -0.176002
# genre     votes      -0.145307
# votes     genre      -0.145307
# score     country    -0.133348
# country   score      -0.133348
# gross     rating     -0.107339
# rating    gross      -0.107339
# year      genre      -0.081261
# genre     year       -0.081261
# country   runtime    -0.078412
# runtime   country    -0.078412
# company   genre      -0.071067
# genre     company    -0.071067
# year      country    -0.070938
# country   year       -0.070938
# runtime   genre      -0.052711
# genre     runtime    -0.052711
# writer    budget     -0.039451
# budget    writer     -0.039451
# genre     country    -0.037615
# country   genre      -0.037615
# company   rating     -0.032943
# rating    company    -0.032943
# star      year       -0.027242
# year      star       -0.027242
# ...

# %%
high_correlation = sorted_pairs[(sorted_pairs) > 0.5]   #sorting for pairs of high correlation

high_correlation
# Out:
# gross     votes       0.630757
# votes     gross       0.630757
# budget    gross       0.740395
# gross     budget      0.740395
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
#Based on this we can identify that 
# Votes and Budget have the highest correlation to Gross Earnings.
